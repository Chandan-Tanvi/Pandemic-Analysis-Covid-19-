# %%
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt


data = pd.read_csv('Cases_TimeSeries.csv') 

data.corr()
# Out:
#                  Daily_Confirmed  Total_Confirmed  Daily_Recovered  \
# Daily_Confirmed         1.000000         0.992277         0.976488
# Total_Confirmed         0.992277         1.000000         0.979668
# Daily_Recovered         0.976488         0.979668         1.000000
# Total_Recovered         0.980572         0.995789         0.976094
# Daily_Deceased          0.754545         0.755140         0.727562
# Total_Deceased          0.991389         0.997452         0.978212
#
#                  Total_Recovered  Daily_Deceased  Total_Deceased
# Daily_Confirmed         0.980572        0.754545        0.991389
# Total_Confirmed         0.995789        0.755140        0.997452
# Daily_Recovered         0.976094        0.727562        0.978212
# Total_Recovered         1.000000        0.729671        0.990800
# Daily_Deceased          0.729671        1.000000        0.770827
# Total_Deceased          0.990800        0.770827        1.000000

# %%
data.Daily_Confirmed.fillna(0)
data.Total_Confirmed.fillna(0)
data.Daily_Recovered.fillna(0)
data.Total_Recovered.fillna(0)
data.Daily_Deceased.fillna(0)
data.Total_Deceased.fillna(0)

# %%
df = data[['Daily_Confirmed','Daily_Recovered',]]
df.head()
# Out:
#    Daily_Confirmed  Daily_Recovered
# 0                1                0
# 1                0                0
# 2                0                0
# 3                1                0
# 4                1                0

# %%
sns.heatmap(df)

# %%
df1 = data[['Total_Confirmed', 'Total_Recovered']]
sns.heatmap(df1)

# %%
df2 = data[['Daily_Recovered', 'Daily_Deceased']]
sns.heatmap(df2)

# %%
data1 = pd.read_csv('HospitalBedsIndia.csv')
data1.head()
# Out:
#    Sno                   State/UT NumPrimaryHealthCenters_HMIS  \
# 0    1  Andaman & Nicobar Islands                           27
# 1    2             Andhra Pradesh                         1417
# 2    3          Arunachal Pradesh                          122
# 3    4                      Assam                         1007
# 4    5                      Bihar                         2007
#
#    NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 0                               4                           NaN
# 1                             198                          31.0
# 2                              62                           NaN
# 3                             166                          14.0
# 4                              63                          33.0
#
#    NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 0                          3                                34
# 1                         20                              1666
# ...

# %%
df3 = data1[['NumPublicBeds_HMIS', 'NumRuralBeds_NHP18', 'NumUrbanBeds_NHP18']]
data1.corr()
# Out:
#                                        Sno  NumCommunityHealthCenters_HMIS  \
# Sno                               1.000000                        0.339718
# NumCommunityHealthCenters_HMIS    0.339718                        1.000000
# NumSubDistrictHospitals_HMIS      0.364751                        0.975144
# NumDistrictHospitals_HMIS         0.321444                        0.991807
# TotalPublicHealthFacilities_HMIS  0.314918                        0.996703
# NumPublicBeds_HMIS                0.312745                        0.993827
# NumRuralHospitals_NHP18           0.343170                        0.980310
# NumRuralBeds_NHP18                0.349407                        0.992747
# NumUrbanHospitals_NHP18           0.339881                        0.986058
# NumUrbanBeds_NHP18                0.342534                        0.987193
#
#                                   NumSubDistrictHospitals_HMIS  \
# Sno                                                   0.364751
# ...

# %%
sns.heatmap(df3)
